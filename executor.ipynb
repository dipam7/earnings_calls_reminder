# %%
import papermill as pm

# %%
pm.execute_notebook('earnings_calls_reminder.ipynb', output_path="companies.txt")
# Out:
# Executing:   0%|          | 0/29 [00:00<?, ?cell/s]
# /Users/dipamvasani/opt/anaconda3/lib/python3.8/site-packages/papermill/iorw.py:140: UserWarning: The specified output file (companies.txt) does not end in one of ['.ipynb', '.json']
#   warnings.warn(
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2022-04-01T01:49:32.607661',
#      'end_time': '2022-04-01T01:49:32.626046',
#      'duration': 0.018385,
#      'status': 'completed'}},
#    'source': '### 0. Installation ',
#    'id': '4a009cc7'},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2022-04-01T01:49:32.639836',
#      'end_time': '2022-04-01T01:49:35.214458',
#      'duration': 2.574622,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2022-04-01T01:49:32.654637Z',
# ...
