# %%
import papermill as pm

# %%
pm.execute_notebook('earnings_calls_reminder.ipynb', output_path="output.ipynb")
# Out:
# Executing:   0%|          | 0/30 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2022-04-02T01:26:49.422079',
#      'end_time': '2022-04-02T01:26:49.440361',
#      'duration': 0.018282,
#      'status': 'completed'}},
#    'source': '### 0. Installation ',
#    'id': 'dd3a35bf'},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2022-04-02T01:26:49.454448',
#      'end_time': '2022-04-02T01:26:49.472220',
#      'duration': 0.017772,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2022-04-02T01:26:49.469635Z',
#      'iopub.execute_input': '2022-04-02T01:26:49.470430Z',
#      'shell.execute_reply': '2022-04-02T01:26:49.471592Z',
#      'iopub.status.idle': '2022-04-02T01:26:49.472098Z'}},
#    'outputs': [],
# ...
